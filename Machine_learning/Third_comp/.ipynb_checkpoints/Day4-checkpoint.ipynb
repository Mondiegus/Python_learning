# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %matplotlib inline

# %%
tf = pd.read_csv('c:\Users\Mondi\Documents\Fax\driving_log.csv',
                 names = ["center", "left", "right", "steering_angle", "throttle", "break", "speed"])
tf.head()
# Out:
#                                           center  \
# 0  D:\===\IMG\center_2019_07_20_19_42_48_364.jpg
# 1  D:\===\IMG\center_2019_07_20_19_42_48_492.jpg
# 2  D:\===\IMG\center_2019_07_20_19_42_48_631.jpg
# 3  D:\===\IMG\center_2019_07_20_19_42_48_758.jpg
# 4  D:\===\IMG\center_2019_07_20_19_42_48_861.jpg
#
#                                           left  \
# 0  D:\===\IMG\left_2019_07_20_19_42_48_364.jpg
# 1  D:\===\IMG\left_2019_07_20_19_42_48_492.jpg
# 2  D:\===\IMG\left_2019_07_20_19_42_48_631.jpg
# 3  D:\===\IMG\left_2019_07_20_19_42_48_758.jpg
# 4  D:\===\IMG\left_2019_07_20_19_42_48_861.jpg
#
#                                           right  steering_angle  throttle  \
# 0  D:\===\IMG\right_2019_07_20_19_42_48_364.jpg             0.0  0.000000
# 1  D:\===\IMG\right_2019_07_20_19_42_48_492.jpg             0.0  0.376879
# 2  D:\===\IMG\right_2019_07_20_19_42_48_631.jpg             0.0  0.743856
# 3  D:\===\IMG\right_2019_07_20_19_42_48_758.jpg             0.0  1.000000
# 4  D:\===\IMG\right_2019_07_20_19_42_48_861.jpg             0.0  1.000000
#
#    break     speed
# 0      0  0.000008
# 1      0  0.638085
# 2      0  1.616566
# 3      0  2.985567
# 4      0  4.395422

# %%
tf["break"].plot()

# %%
img = Image.open(tf["left"][0])
plt.imshow(img)

# %%
img = np.asarray(img)
img.shape
# Out:
# (160, 320, 3)

# %%
def loadimage(fname):
    return np.asarray(Image.open(fname))

# %%
def processImage(img):
    return img[10:130:2, ::4,:]

# %%
img = processImage(loadimage(tf["center"][0]))
plt.imshow(img)

# %%
X = [processImage(loadimage(fname)) for fname in tf["center"]]
X += [processImage(loadimage(fname)) for fname in tf["left"]]
X += [processImage(loadimage(fname)) for fname in tf["right"]]
y = np.array(tf["steering_angle"])
y = np.concatenate([y, y+0.4, y-0.4])

# %%
X = np.array(X)
print(X.shape)
print(y.shape)
# Out:
# (3675, 60, 80, 3)
# (3675,)

# %%
plt.plot(y)
plt.show();

# %%
np.save('d:\X.npy',X)
np.save('d:\Y.npy',y)
